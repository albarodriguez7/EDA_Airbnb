# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
plt.rcParams.update({'axes.titlesize':16, 'axes.labelsize':14, 'xtick.labelsize':12, 'ytick.labelsize':12})

df = pd.read_csv("src/data/airbnb_madrid_clean_final.csv")

# %%
df = pd.read_csv("src/data/airbnb_madrid_clean_final.csv")
df
# Out:
#       host_response_time  host_has_profile_pic  host_identity_verified  \
# 0         within an hour                  True                    True
# 1         within an hour                  True                    True
# 2         within an hour                  True                    True
# 3         within an hour                  True                    True
# 4         within an hour                  True                    True
# ...                  ...                   ...                     ...
# 15020     within an hour                  True                    True
# 15021     within an hour                  True                    True
# 15022     within an hour                  True                    True
# 15023     within an hour                 False                    True
# 15024     within an hour                  True                    True
#
#       neighbourhood_cleansed                property_type        room_type  \
# 0                        Sol           Entire rental unit  Entire home/apt
# 1                Universidad           Entire rental unit  Entire home/apt
# 2                   Justicia  Private room in rental unit     Private room
# 3                Universidad           Entire rental unit  Entire home/apt
# 4                Universidad           Entire rental unit  Entire home/apt
# ...                      ...                          ...              ...
# 15020               Almenara  Private room in rental unit     Private room
# 15021                Palacio           Entire rental unit  Entire home/apt
# 15022              San Diego           Entire rental unit  Entire home/apt
# 15023       Apostol Santiago  Private room in rental unit     Private room
# 15024                Palacio           Entire rental unit  Entire home/apt
#
#        accommodates  bathrooms  bedrooms  beds  ...  number_of_reviews_ltm  \
# 0                 2        1.0       1.0   2.0  ...                      1
# 1                 2        1.0       1.0   3.0  ...                      4
# 2                 4        1.5       1.0   2.0  ...                     41
# 3                 2        1.0       1.0   1.0  ...                      1
# 4                 2        1.0       1.0   2.0  ...                      2
# ...             ...        ...       ...   ...  ...                    ...
# 15020             2        1.0       1.0   1.0  ...                      2
# 15021             2        1.0       1.0   1.0  ...                      4
# 15022             6        1.0       2.0   4.0  ...                      1
# 15023             2        0.5       1.0   1.0  ...                      1
# 15024             4        1.0       1.0   2.0  ...                      1
#
#        number_of_reviews_l30d  review_scores_accuracy  \
# 0                           1                    4.71
# 1                           1                    4.71
# 2                           4                    4.78
# 3                           0                    4.49
# 4                           0                    4.65
# ...                       ...                     ...
# 15020                       2                    5.00
# 15021                       4                    5.00
# 15022                       1                    5.00
# 15023                       1                    5.00
# 15024                       1                    5.00
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.88                   4.82
# 1                           4.90                   4.87
# 2                           4.46                   4.80
# 3                           4.42                   4.43
# 4                           4.55                   4.80
# ...                          ...                    ...
# 15020                       5.00                   5.00
# 15021                       5.00                   5.00
# 15022                       5.00                   5.00
# 15023                       5.00                   5.00
# 15024                       5.00                   5.00
#
#        review_scores_communication  review_scores_location  \
# 0                             4.78                    4.90
# 1                             4.81                    4.88
# 2                             4.86                    4.97
# 3                             4.40                    4.60
# 4                             4.71                    4.87
# ...                            ...                     ...
# 15020                         5.00                    5.00
# 15021                         5.00                    5.00
# 15022                         5.00                    5.00
# 15023                         5.00                    5.00
# 15024                         5.00                    5.00
#
#        review_scores_value  review_score_mean       review_tier
# 0                     4.69           4.796667    Alta (4.5–4.8]
# 1                     4.59           4.793333    Alta (4.5–4.8]
# 2                     4.60           4.745000    Alta (4.5–4.8]
# 3                     4.09           4.405000   Media (4.0–4.5]
# 4                     4.10           4.613333    Alta (4.5–4.8]
# ...                    ...                ...               ...
# 15020                 5.00           5.000000  Excelente (>4.8)
# 15021                 5.00           5.000000  Excelente (>4.8)
# 15022                 5.00           5.000000  Excelente (>4.8)
# 15023                 5.00           5.000000  Excelente (>4.8)
# 15024                 5.00           5.000000  Excelente (>4.8)
#
# [15025 rows x 29 columns]

# %%
# ¿Hay diferencias de precio entre barrios?

top_neigh = df['neighbourhood_cleansed'].value_counts().head(10).index

plt.figure(figsize=(10,5))
sns.boxplot(
    data=df[df['neighbourhood_cleansed'].isin(top_neigh)],
    x='neighbourhood_cleansed',
    y='price'
)
plt.title('Precio por barrio (Top 10 más frecuentes)')
plt.xticks(rotation=45)
plt.show()

# %%
top_neigh = df['neighbourhood_cleansed'].value_counts().head(10).index

plt.figure(figsize=(12,6))
sns.boxplot(
    data=df[df['neighbourhood_cleansed'].isin(top_neigh)],
    x='neighbourhood_cleansed',
    y='price',
    palette='pastel'
)
plt.title('Precio promedio de alojamientos por barrio')
plt.xlabel('Barrio')
plt.ylabel('Precio (USD)')
plt.xticks(rotation=45)
plt.show()


# Los barrios mas caros son los que tienen las cajas mas altas
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3944\4255913574.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
# ¿Cómo cambia el precio según el tipo de habitación?

plt.figure(figsize=(8,5))
sns.boxplot(
    data=df,
    x='room_type',
    y='price'
)
plt.title('Precio según tipo de habitación')
plt.show()

# %%
# ¿Los alojamientos con mayor capacidad (accommodates) tienen un precio más alto?

plt.figure(figsize=(8,5))
sns.scatterplot(
    data=df,
    x='accommodates',
    y='price',
    alpha=0.5
)
sns.regplot(
    data=df,
    x='accommodates',
    y='price',
    scatter=False,
    color='red'
)
plt.title('Precio vs Capacidad del alojamiento')
plt.show()

# %%
#  ¿Un precio alto implica mejores puntuaciones?

review_cols = [
    'review_scores_accuracy', 'review_scores_cleanliness',
    'review_scores_checkin', 'review_scores_communication',
    'review_scores_location', 'review_scores_value'
]

plt.figure(figsize=(8,6))
sns.heatmap(
    df[review_cols + ['price']].corr(),
    annot=True, cmap='coolwarm'
)
plt.title('Correlación entre precio y puntuaciones')
plt.show()

# %%
#  ¿Los anfitriones con perfil verificado reciben mejores valoraciones?

plt.figure(figsize=(7,5))
sns.boxplot(
    data=df,
    x='host_identity_verified',
    y='review_scores_communication'
)
plt.title('Valoración de comunicación según verificación del host')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(
    data=df.melt(id_vars=['host_identity_verified'], value_vars=review_cols, 
                 var_name='review_type', value_name='score'),
    x='review_type',
    y='score',
    hue='host_identity_verified'
)
plt.title('Comparación de puntuaciones por verificación del host')
plt.xticks(rotation=45)
plt.show()

# %%
#  ¿A mayor número de noches el precio medio por noche es inferior?

# Precio medio por noche
df['price_per_night'] = df['price'] / df['minimum_nights']

plt.figure(figsize=(8,5))
sns.scatterplot(
    data=df[df['minimum_nights'] < 365],  # filtramos valores extremos
    x='minimum_nights',
    y='price_per_night',
    alpha=0.4
)
sns.regplot(
    data=df[df['minimum_nights'] < 365],
    x='minimum_nights',
    y='price_per_night',
    scatter=False,
    color='red'
)
plt.title('Precio medio por noche vs Número mínimo de noches')
plt.show()
