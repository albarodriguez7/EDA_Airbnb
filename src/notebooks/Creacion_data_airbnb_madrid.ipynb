# %%
import pandas as pd

# %%
# Importo el archivo csv completo que hemos cogido de internet

df = pd.read_csv("../data/listings.csv.gz", compression="gzip")
df
# Out:
#                         id                                       listing_url  \
# 0                    21853                https://www.airbnb.com/rooms/21853
# 1                    30320                https://www.airbnb.com/rooms/30320
# 2                    30959                https://www.airbnb.com/rooms/30959
# 3                    40916                https://www.airbnb.com/rooms/40916
# 4                    62423                https://www.airbnb.com/rooms/62423
# ...                    ...                                               ...
# 24995  1508016618526988093  https://www.airbnb.com/rooms/1508016618526988093
# 24996  1508029370917448986  https://www.airbnb.com/rooms/1508029370917448986
# 24997  1508295390166110966  https://www.airbnb.com/rooms/1508295390166110966
# 24998  1508573408483646673  https://www.airbnb.com/rooms/1508573408483646673
# 24999  1508659056613604207  https://www.airbnb.com/rooms/1508659056613604207
#
# ...

# %%
# Filtramos las columnas con las que nos queremos quedar y que nos van a ser útiles, las demás las descartamos

df_definitiva = df[["id", "name", "host_id", "host_response_time", "host_has_profile_pic", "host_identity_verified", "neighbourhood_cleansed", "property_type", "room_type", "accommodates", "bathrooms", "bedrooms", "beds", "price", "minimum_nights", "maximum_nights", "minimum_nights_avg_ntm", "maximum_nights_avg_ntm", "availability_30", "availability_60", "availability_90", "number_of_reviews", "number_of_reviews_ltm", "number_of_reviews_l30d", "review_scores_accuracy", "review_scores_cleanliness", "review_scores_checkin", "review_scores_communication", "review_scores_location", "review_scores_value"]]

# %%
df_definitiva
# Out:
#                         id                                               name  \
# 0                    21853                               Bright and airy room
# 1                    30320                              Apartamentos Dana Sol
# 2                    30959                    Beautiful loft in Madrid Center
# 3                    40916                        Apartasol Apartamentos Dana
# 4                    62423       MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID
# ...                    ...                                                ...
# 24995  1508016618526988093                     Amplio apartamento con Terraza
# 24996  1508029370917448986   Piso de hasta 4 huéspedes en el centro de Madrid
# 24997  1508295390166110966  Cozy Apartment Gran Via Wifi Air Conditioner/Heat
# 24998  1508573408483646673                                          Casa Nido
# 24999  1508659056613604207                    Cómoda habitación muy céntrica.
#
# ...

# %%
df_definitiva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           25000 non-null  int64
#  1   name                         25000 non-null  object
#  2   host_id                      25000 non-null  int64
#  3   host_response_time           20115 non-null  object
#  4   host_has_profile_pic         24903 non-null  object
#  5   host_identity_verified       24903 non-null  object
#  6   neighbourhood_cleansed       25000 non-null  object
#  7   property_type                25000 non-null  object
#  8   room_type                    25000 non-null  object
#  9   accommodates                 25000 non-null  int64
#  10  bathrooms                    18960 non-null  float64
#  11  bedrooms                     22488 non-null  float64
#  12  beds                         18965 non-null  float64
# ...

# %%
df_definitiva.isnull().sum().sort_values(ascending=False)
# Out:
# price                          6047
# bathrooms                      6040
# beds                           6035
# review_scores_value            5151
# review_scores_location         5150
# review_scores_checkin          5148
# review_scores_cleanliness      5148
# review_scores_communication    5147
# review_scores_accuracy         5147
# host_response_time             4885
# bedrooms                       2512
# host_has_profile_pic             97
# host_identity_verified           97
# host_id                           0
# neighbourhood_cleansed            0
# property_type                     0
# room_type                         0
# accommodates                      0
# name                              0
# id                                0
# minimum_nights                    0
# maximum_nights                    0
# number_of_reviews                 0
# availability_90                   0
# availability_60                   0
# availability_30                   0
# ...

# %%
df_definitiva = df_definitiva.dropna(subset=["bathrooms", "review_scores_checkin", "host_response_time", "bedrooms", "beds", "review_scores_cleanliness"])

# %%
df_definitiva.isnull().sum().sort_values(ascending=False)
# Out:
# price                          11
# id                              0
# host_id                         0
# host_response_time              0
# host_has_profile_pic            0
# name                            0
# host_identity_verified          0
# neighbourhood_cleansed          0
# room_type                       0
# property_type                   0
# accommodates                    0
# bathrooms                       0
# bedrooms                        0
# beds                            0
# minimum_nights                  0
# maximum_nights                  0
# minimum_nights_avg_ntm          0
# maximum_nights_avg_ntm          0
# availability_30                 0
# availability_60                 0
# availability_90                 0
# number_of_reviews               0
# number_of_reviews_ltm           0
# number_of_reviews_l30d          0
# review_scores_accuracy          0
# review_scores_cleanliness       0
# review_scores_checkin           0
# ...

# %%
df_definitiva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15036 entries, 1 to 24991
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           15036 non-null  int64
#  1   name                         15036 non-null  object
#  2   host_id                      15036 non-null  int64
#  3   host_response_time           15036 non-null  object
#  4   host_has_profile_pic         15036 non-null  object
#  5   host_identity_verified       15036 non-null  object
#  6   neighbourhood_cleansed       15036 non-null  object
#  7   property_type                15036 non-null  object
#  8   room_type                    15036 non-null  object
#  9   accommodates                 15036 non-null  int64
#  10  bathrooms                    15036 non-null  float64
#  11  bedrooms                     15036 non-null  float64
#  12  beds                         15036 non-null  float64
# ...

# %%
# Aquí cremos un nuevo csv, lo comentamos porque si no se vuelve a crear y ya está metido en la carpeta de data

# df_definitiva.to_csv('data_airbnb_madrid.csv', sep=';', index=False)

# %%
df_definitiva
# Out:
#                         id                                               name  \
# 1                    30320                              Apartamentos Dana Sol
# 3                    40916                        Apartasol Apartamentos Dana
# 4                    62423       MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID
# 6                    70073               Adorable Apartment Malasaña-Gran Via
# 7                    70310    Heart of Malasaña Cozy, Quiet & Sunny Apartment
# ...                    ...                                                ...
# 24848  1502822056090801867                             Habitació en chamartín
# 24866  1503513535420478247              Apartamento en el centro de la ciudad
# 24881  1504175224287178517          Bonito apartamento a 5 minutos de Atocha.
# 24926  1505694082550770013  Habitación cerca del aeropuerto, piso compartido!
# 24991  1507409317740478788              Nuevo apartamento, vistas a Gran Vía.
#
# ...

# %%
df_definitiva["host_response_time"].unique()
# Out:
# array(['within an hour', 'within a few hours', 'within a day',
#        'a few days or more'], dtype=object)

# %%
df_definitiva["host_response_time"].value_counts()
# Out:
# host_response_time
# within an hour        11757
# within a few hours     1688
# within a day           1143
# a few days or more      448
# Name: count, dtype: int64

# %%
df_definitiva["property_type"].value_counts()
# Out:
# property_type
# Entire rental unit                    10141
# Private room in rental unit            2549
# Private room in home                    343
# Entire loft                             336
# Entire condo                            279
# Entire serviced apartment               231
# Entire home                             164
# Room in hotel                           156
# Private room in hostel                  133
# Private room in condo                   123
# Private room in bed and breakfast        86
# Room in aparthotel                       58
# Private room in casa particular          56
# Shared room in hostel                    45
# Room in hostel                           30
# Private room in guesthouse               30
# Shared room in bed and breakfast         25
# Shared room in rental unit               19
# Private room in townhouse                18
# Private room in serviced apartment       16
# Entire guest suite                       15
# ...

# %%
df_definitiva.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_response_time', 'host_has_profile_pic',
#        'host_identity_verified', 'neighbourhood_cleansed', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'availability_30', 'availability_60',
#        'availability_90', 'number_of_reviews', 'number_of_reviews_ltm',
#        'number_of_reviews_l30d', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value'],
#       dtype='object')
